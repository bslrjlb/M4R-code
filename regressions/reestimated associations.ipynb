# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from linearmodels import PanelOLS
from scipy.stats.mstats import winsorize 
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# %%
regression_data = pd.read_csv('merged_data_sss.csv')

# %%
regression_data['gvkey'].nunique()
# Out:
# 1423

# %%
# check
regression_data = regression_data.drop('Unnamed: 0', axis=1)
regression_data.describe()
# Out:
#                gvkey         fyear         month           RET           MOM  \
# count   81605.000000  81605.000000  81605.000000  81605.000000  81605.000000
# mean    61120.654923   2017.409767      6.522738      1.285111      0.120438
# std     69006.711553      2.158369      3.451686     12.473213      0.432692
# min      1004.000000   2011.000000      1.000000    -87.697842     -0.832704
# 25%     10860.000000   2016.000000      4.000000     -4.819277     -0.124580
# 50%     24783.000000   2018.000000      7.000000      1.053142      0.082349
# 75%    133869.000000   2019.000000     10.000000      6.870229      0.297905
# max    328795.000000   2020.000000     12.000000     99.191686      3.250000
#
#                BETA         VOLAT  total_emission_scope1  \
# count  81605.000000  81605.000000           81605.000000
# mean       1.195033      0.103849              10.411239
# std        0.727854      0.057046               2.689473
# min       -1.044560      0.025872               0.693147
# 25%        0.757661      0.063082               8.641213
# 50%        1.119520      0.090176              10.219274
# 75%        1.546813      0.129241              11.925332
# max        4.147888      0.356740              18.713283
#
#        total_emission_scope2  emission_growth_scope1  ...  \
# count           81605.000000            81605.000000  ...
# mean               10.627489                0.053134  ...
# std                 2.067171                0.296586  ...
# min                 2.544276               -0.587399  ...
# 25%                 9.258057               -0.074867  ...
# 50%                10.620766                0.025733  ...
# 75%                12.018952                0.137206  ...
# max                16.571679                1.124937  ...
#
#        carbon_intensity_scope2       LOGSIZE           B/M      LEVERAGE  \
# count             81605.000000  81605.000000  81605.000000  81605.000000
# mean                  0.314301      8.235747      0.577298      0.275880
# std                   0.381090      1.762027      0.530395      0.215301
# min                   0.008185     -4.612195     -0.040954      0.000000
# 25%                   0.085381      7.070696      0.230611      0.088988
# 50%                   0.176111      8.231717      0.444195      0.251456
# 75%                   0.377914      9.407562      0.758144      0.412147
# max                   1.780249     14.627616      2.663034      0.814584
#
#            INVEST/A           ROE        LOGPPE       SALESGR         EPSGR  \
# count  81605.000000  81605.000000  81605.000000  81605.000000  81605.000000
# mean       0.035363      7.217507      6.841127      0.011243      0.004939
# std        0.033117     33.035337      2.093872      0.328364      0.227102
# min        0.000000   -109.224422     -2.465104     -2.260408     -1.598919
# 25%        0.012404      0.751054      5.498769     -0.015899     -0.022173
# 50%        0.025776     10.303030      6.880971      0.021430      0.003362
# 75%        0.047656     19.134897      8.165563      0.073998      0.027182
# max        0.163615     91.432361     13.144907      1.647431      1.808117
#
#                RET1
# count  81605.000000
# mean      17.425595
# std       53.736741
# min      -95.067633
# 25%       -9.791332
# 50%       11.590107
# 75%       34.970843
# max     1042.570281
#
# [8 rows x 22 columns]

# %%
regression_data.columns
# Out:
# Index(['gvkey', 'fyear', 'month', 'RET', 'MOM', 'BETA', 'VOLAT',
#        'total_emission_scope1', 'total_emission_scope2',
#        'emission_growth_scope1', 'emission_growth_scope2',
#        'carbon_intensity_scope1', 'carbon_intensity_scope2', 'LOGSIZE', 'B/M',
#        'LEVERAGE', 'INVEST/A', 'ROE', 'LOGPPE', 'SALESGR', 'EPSGR', 'RET1',
#        'datatime', 'GICS_level_1'],
#       dtype='object')

# %%
regression_data = regression_data.sort_values(by=['gvkey', 'fyear', 'month'])

columns_to_shift = ['RET', 'MOM', 'BETA', 'VOLAT',
       'total_emission_scope1', 'total_emission_scope2',
       'emission_growth_scope1', 'emission_growth_scope2',
       'carbon_intensity_scope1', 'carbon_intensity_scope2', 'LOGSIZE', 'B/M',
       'LEVERAGE', 'INVEST/A', 'ROE', 'LOGPPE', 'SALESGR', 'EPSGR', 'RET1']

def shift_if_consecutive(group):
    group = group.sort_values(by='datatime')
    
    group['datatime'] = pd.to_datetime(group['datatime'])
    
    # check if data is consecutive on year-month
    group['consecutive'] = group['datatime'].diff().dt.days <= 31
    
    for col in columns_to_shift:
        group[f'{col}_t-1'] = group[col].shift(-1)
        group[f'{col}_t-1'] = group.apply(lambda row: row[col] if not row['consecutive'] else row[f'{col}_t-1'], axis=1)
        group[f'{col}_t+1'] = group[col].shift(+1)
        group[f'{col}_t+1'] = group.apply(lambda row: row[col] if not row['consecutive'] else row[f'{col}_t+1'], axis=1)
    
    return group.drop(columns=['consecutive', 'datatime'])

# apply to each gvkey group
regression_data_shifted = regression_data.groupby('gvkey').apply(shift_if_consecutive)
regression_data_shifted.columns = [col.replace('/', '_') for col in regression_data_shifted.columns]

print(regression_data_shifted.head())
# Out:
#          gvkey  fyear  month       RET       MOM      BETA     VOLAT  \
# gvkey
# 1004  0   1004   2017      1 -1.815431  0.433590  1.728236  0.106410
#       1   1004   2017      2  3.790447  0.695722  1.697156  0.106333
#       2   1004   2017      3 -0.148456  0.499601  1.585366  0.106969
#       3   1004   2017      4  7.017544  0.432948  1.536825  0.107289
#       4   1004   2017      5 -3.834398  0.448269  1.553771  0.109533
#
#          total_emission_scope1  total_emission_scope2  emission_growth_scope1  \
# gvkey
# 1004  0              10.991192              10.418976               -0.004909
#       1              10.991192              10.418976               -0.004909
#       2              10.991192              10.418976               -0.004909
#       3              10.991192              10.418976               -0.004909
#       4              10.991192              10.418976               -0.004909
#
#          ...   ROE_t-1   ROE_t+1  LOGPPE_t-1  LOGPPE_t+1  SALESGR_t-1  \
# gvkey    ...
# 1004  0  ...  1.666133  1.666133    6.274762    6.274762    -0.016998
#       1  ...  1.666133  1.666133    6.274762    6.274762    -0.016998
#       2  ...  1.666133  1.666133    6.274762    6.274762    -0.016998
#       3  ...  1.666133  1.666133    6.274762    6.274762    -0.016998
#       4  ...  1.666133  1.666133    6.274762    6.274762    -0.016998
#
#          SALESGR_t+1  EPSGR_t-1  EPSGR_t+1   RET1_t-1   RET1_t+1
# gvkey
# 1004  0    -0.016998   0.016008   0.016008  19.881626  19.881626
#       1    -0.016998   0.016008   0.016008  19.881626  19.881626
#       2    -0.016998   0.016008   0.016008  19.881626  19.881626
#       3    -0.016998   0.016008   0.016008  19.881626  19.881626
#       4    -0.016998   0.016008   0.016008  19.881626  19.881626
#
# [5 rows x 61 columns]
# C:\Users\18906\AppData\Local\Temp\ipykernel_13368\3228673918.py:26: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   regression_data_shifted = regression_data.groupby('gvkey').apply(shift_if_consecutive)

# %%
regression_data_shifted = regression_data_shifted.replace([np.inf, -np.inf], np.nan)

# %%
regression_data_shifted.columns
# Out:
# Index(['gvkey', 'fyear', 'month', 'RET', 'MOM', 'BETA', 'VOLAT',
#        'total_emission_scope1', 'total_emission_scope2',
#        'emission_growth_scope1', 'emission_growth_scope2',
#        'carbon_intensity_scope1', 'carbon_intensity_scope2', 'LOGSIZE', 'B_M',
#        'LEVERAGE', 'INVEST_A', 'ROE', 'LOGPPE', 'SALESGR', 'EPSGR', 'RET1',
#        'GICS_level_1', 'RET_t-1', 'RET_t+1', 'MOM_t-1', 'MOM_t+1', 'BETA_t-1',
#        'BETA_t+1', 'VOLAT_t-1', 'VOLAT_t+1', 'total_emission_scope1_t-1',
#        'total_emission_scope1_t+1', 'total_emission_scope2_t-1',
#        'total_emission_scope2_t+1', 'emission_growth_scope1_t-1',
#        'emission_growth_scope1_t+1', 'emission_growth_scope2_t-1',
#        'emission_growth_scope2_t+1', 'carbon_intensity_scope1_t-1',
#        'carbon_intensity_scope1_t+1', 'carbon_intensity_scope2_t-1',
#        'carbon_intensity_scope2_t+1', 'LOGSIZE_t-1', 'LOGSIZE_t+1', 'B_M_t-1',
#        'B_M_t+1', 'LEVERAGE_t-1', 'LEVERAGE_t+1', 'INVEST_A_t-1',
#        'INVEST_A_t+1', 'ROE_t-1', 'ROE_t+1', 'LOGPPE_t-1', 'LOGPPE_t+1',
#        'SALESGR_t-1', 'SALESGR_t+1', 'EPSGR_t-1', 'EPSGR_t+1', 'RET1_t-1',
#        'RET1_t+1'],
#       dtype='object')

# %% [markdown]
# ### Regression on Log(Emission Scope1)

# %%
shifted_columns1 = ['RET_t+1', 'RET1_t+1', 'total_emission_scope1', 'LOGSIZE_t-1', 
                'LEVERAGE', 'INVEST_A', 'LOGPPE_t-1', 'SALESGR']

reg_data1 = regression_data_shifted.dropna(subset=shifted_columns1)

Y1 = reg_data1['RET_t+1']
X1 = reg_data1[['total_emission_scope1', 'LOGSIZE_t-1', 
                'LEVERAGE', 'INVEST_A', 'LOGPPE_t-1', 'SALESGR']]

X1 = sm.add_constant(X1)

model1 = sm.OLS(Y1, X1)

results1 = model1.fit(cov_type='cluster', cov_kwds={'groups': reg_data1[['gvkey']].values})

print(results1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                RET_t+1   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     50.16
# Date:                Mon, 24 Jun 2024   Prob (F-statistic):           4.13e-56
# Time:                        06:44:42   Log-Likelihood:            -3.1338e+05
# No. Observations:               80201   AIC:                         6.268e+05
# Df Residuals:                   80194   BIC:                         6.268e+05
# Df Model:                           6
# Covariance Type:              cluster
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -1.8764      0.287     -6.532      0.000      -2.439      -1.313
# total_emission_scope1     0.0244      0.025      0.957      0.339      -0.026       0.074
# LOGSIZE_t-1               0.7385      0.048     15.300      0.000       0.644       0.833
# LEVERAGE                 -0.1695      0.194     -0.873      0.383      -0.550       0.211
# INVEST_A                  8.0644      1.605      5.025      0.000       4.919      11.210
# LOGPPE_t-1               -0.5504      0.060     -9.172      0.000      -0.668      -0.433
# SALESGR                   0.9467      0.234      4.052      0.000       0.489       1.405
# ==============================================================================
# Omnibus:                    13575.290   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           123835.749
# Skew:                           0.549   Prob(JB):                         0.00
# Kurtosis:                       8.988   Cond. No.                         528.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)

# %%
coeffs = results1.params
p_vals = results1.pvalues
print(p_vals)
# Out:
# const                    6.482576e-11
# total_emission_scope1    3.386416e-01
# LOGSIZE_t-1              7.694063e-53
# LEVERAGE                 3.828914e-01
# INVEST_A                 5.027683e-07
# LOGPPE_t-1               4.654506e-20
# SALESGR                  5.087973e-05
# dtype: float64

# %%
Y2 = reg_data1['RET_t+1']
X2 = reg_data1[['total_emission_scope1', 'LOGSIZE_t-1', 
                'LEVERAGE', 'INVEST_A', 'LOGPPE_t-1', 'SALESGR']]

############# year fixed effect ##############
year_dummies = pd.get_dummies(reg_data1['fyear'], prefix='year')
year_dummies = year_dummies.iloc[:, 1:]
year_dummies = year_dummies.astype(int)

############# month fixed effect ##############
month_dummies = pd.get_dummies(reg_data1['month'], prefix='month')
month_dummies = month_dummies.iloc[:, 1:]
month_dummies = month_dummies.astype(int)

X2 = pd.concat([X2, year_dummies], axis=1)
X2 = pd.concat([X2, month_dummies], axis=1)

X2 = sm.add_constant(X2)

model2 = sm.OLS(Y2, X2)

results2 = model2.fit()

print(results2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                RET_t+1   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     133.4
# Date:                Mon, 24 Jun 2024   Prob (F-statistic):               0.00
# Time:                        06:44:36   Log-Likelihood:            -3.1199e+05
# No. Observations:               80201   AIC:                         6.240e+05
# Df Residuals:                   80174   BIC:                         6.243e+05
# Df Model:                          26
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -4.4664      0.663     -6.741      0.000      -5.765      -3.168
# total_emission_scope1     0.0210      0.025      0.854      0.393      -0.027       0.069
# LOGSIZE_t-1               0.7318      0.034     21.482      0.000       0.665       0.799
# LEVERAGE                 -0.1465      0.194     -0.753      0.451      -0.528       0.235
# INVEST_A                  7.8288      1.447      5.410      0.000       4.992      10.665
# LOGPPE_t-1               -0.5520      0.040    -13.862      0.000      -0.630      -0.474
# SALESGR                   0.8509      0.133      6.399      0.000       0.590       1.112
# year_2012                 2.0515      0.666      3.078      0.002       0.745       3.358
# year_2013                 3.0790      0.629      4.893      0.000       1.846       4.312
# year_2014                 0.7438      0.617      1.206      0.228      -0.465       1.952
# year_2015                -0.1000      0.614     -0.163      0.871      -1.304       1.104
# year_2016                 1.1504      0.614      1.875      0.061      -0.052       2.353
# year_2017                 1.5134      0.603      2.509      0.012       0.331       2.696
# year_2018                 0.4643      0.603      0.770      0.441      -0.717       1.646
# year_2019                 1.1583      0.603      1.922      0.055      -0.023       2.339
# year_2020                 0.9032      0.604      1.495      0.135      -0.281       2.087
# month_2                   3.3399      0.204     16.376      0.000       2.940       3.740
# month_3                   1.4099      0.204      6.915      0.000       1.010       1.810
# month_4                  -3.6094      0.204    -17.711      0.000      -4.009      -3.210
# month_5                   4.1737      0.204     20.490      0.000       3.774       4.573
# month_6                   2.8936      0.203     14.221      0.000       2.495       3.292
# month_7                   2.6428      0.203     12.994      0.000       2.244       3.041
# month_8                   3.7825      0.203     18.604      0.000       3.384       4.181
# month_9                   1.0027      0.203      4.934      0.000       0.604       1.401
# month_10                  0.9378      0.203      4.617      0.000       0.540       1.336
# month_11                  0.0835      0.203      0.411      0.681      -0.315       0.482
# month_12                  3.8321      0.216     17.706      0.000       3.408       4.256
# ==============================================================================
# Omnibus:                    14674.055   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           123832.605
# Skew:                           0.645   Prob(JB):                         0.00
# Kurtosis:                       8.949   Cond. No.                         694.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
Y3 = reg_data1['RET_t+1']
X3 = reg_data1[['total_emission_scope1', 'LOGSIZE_t-1', 
                'LEVERAGE', 'INVEST_A', 'LOGPPE_t-1', 'SALESGR']]

############# year fixed effect ##############
year_dummies = pd.get_dummies(reg_data1['fyear'], prefix='year')
year_dummies = year_dummies.iloc[:, 1:]
year_dummies = year_dummies.astype(int)

############# month fixed effect ##############
month_dummies = pd.get_dummies(reg_data1['month'], prefix='month')
month_dummies = month_dummies.iloc[:, 1:]
month_dummies = month_dummies.astype(int)

############# industry fixed effect ##############
industry_dummies = pd.get_dummies(reg_data1['GICS_level_1'], prefix='industry')
industry_dummies = industry_dummies.iloc[:, 1:]
industry_dummies = industry_dummies.astype(int)

X3 = pd.concat([X3, year_dummies], axis=1)
X3 = pd.concat([X3, month_dummies], axis=1)
X3 = pd.concat([X3, industry_dummies], axis=1)

X3 = sm.add_constant(X3)

model3 = sm.OLS(Y3, X3)

results3 = model3.fit()

print(results3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                RET_t+1   R-squared:                       0.043
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     99.03
# Date:                Mon, 24 Jun 2024   Prob (F-statistic):               0.00
# Time:                        06:44:32   Log-Likelihood:            -3.1194e+05
# No. Observations:               80201   AIC:                         6.240e+05
# Df Residuals:                   80164   BIC:                         6.243e+05
# Df Model:                          36
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              -4.5159      0.695     -6.500      0.000      -5.878      -3.154
# total_emission_scope1              -0.0138      0.031     -0.438      0.662      -0.075       0.048
# LOGSIZE_t-1                         0.7540      0.037     20.608      0.000       0.682       0.826
# LEVERAGE                           -0.1687      0.195     -0.866      0.386      -0.550       0.213
# INVEST_A                            8.4450      1.507      5.604      0.000       5.491      11.399
# LOGPPE_t-1                         -0.5381      0.042    -12.914      0.000      -0.620      -0.456
# SALESGR                             0.8050      0.133      6.032      0.000       0.543       1.067
# year_2012                           2.0603      0.667      3.090      0.002       0.754       3.367
# year_2013                           3.0897      0.629      4.909      0.000       1.856       4.323
# year_2014                           0.7371      0.617      1.195      0.232      -0.472       1.946
# year_2015                          -0.0963      0.615     -0.157      0.875      -1.301       1.109
# year_2016                           1.1475      0.614      1.869      0.062      -0.056       2.351
# year_2017                           1.4948      0.604      2.477      0.013       0.312       2.678
# year_2018                           0.4518      0.603      0.749      0.454      -0.730       1.634
# year_2019                           1.1435      0.603      1.897      0.058      -0.038       2.325
# year_2020                           0.8783      0.605      1.452      0.146      -0.307       2.063
# month_2                             3.3402      0.204     16.386      0.000       2.941       3.740
# month_3                             1.4097      0.204      6.917      0.000       1.010       1.809
# month_4                            -3.6090      0.204    -17.718      0.000      -4.008      -3.210
# month_5                             4.1744      0.204     20.504      0.000       3.775       4.573
# month_6                             2.8945      0.203     14.233      0.000       2.496       3.293
# month_7                             2.6436      0.203     13.004      0.000       2.245       3.042
# month_8                             3.7835      0.203     18.619      0.000       3.385       4.182
# month_9                             1.0035      0.203      4.940      0.000       0.605       1.402
# month_10                            0.9385      0.203      4.623      0.000       0.541       1.336
# month_11                            0.0838      0.203      0.413      0.680      -0.314       0.482
# month_12                            3.8288      0.216     17.699      0.000       3.405       4.253
# industry_Consumer Discretionary     0.2548      0.238      1.070      0.285      -0.212       0.721
# industry_Consumer Staple           -0.2503      0.283     -0.885      0.376      -0.805       0.304
# industry_Energy                    -0.8135      0.311     -2.617      0.009      -1.423      -0.204
# industry_Financial                 -0.4409      0.248     -1.775      0.076      -0.928       0.046
# industry_Health Care                0.2093      0.238      0.878      0.380      -0.258       0.677
# industry_Industrial                 0.2831      0.234      1.212      0.226      -0.175       0.741
# industry_Information Technology     0.5244      0.233      2.253      0.024       0.068       0.981
# industry_Material                   0.4217      0.281      1.501      0.133      -0.129       0.972
# industry_Real Estate               -1.1277      0.340     -3.312      0.001      -1.795      -0.460
# industry_Utilities                  0.6590      0.355      1.855      0.064      -0.037       1.355
# ==============================================================================
# Omnibus:                    14691.817   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           124029.517
# Skew:                           0.646   Prob(JB):                         0.00
# Kurtosis:                       8.954   Cond. No.                         695.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Regression on Log(Emission Scope2)

# %%
shifted_columns2 = ['RET_t+1', 'RET1_t+1', 'total_emission_scope2', 'LOGSIZE_t-1', 
                'LEVERAGE', 'INVEST_A', 'LOGPPE_t-1', 'SALESGR']
reg_data2 = regression_data_shifted.dropna(subset=shifted_columns2)

Y4 = reg_data2['RET_t+1']
X4 = reg_data2[['total_emission_scope2', 'LOGSIZE_t-1', 
                'LEVERAGE', 'INVEST_A', 'LOGPPE_t-1', 'SALESGR']]

X4 = sm.add_constant(X4)

model4 = sm.OLS(Y4, X4)

results4 = model4.fit()

print(results4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                RET_t+1   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     101.9
# Date:                Mon, 24 Jun 2024   Prob (F-statistic):          2.57e-128
# Time:                        01:46:53   Log-Likelihood:            -3.1338e+05
# No. Observations:               80201   AIC:                         6.268e+05
# Df Residuals:                   80194   BIC:                         6.268e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -1.3250      0.273     -4.848      0.000      -1.861      -0.789
# total_emission_scope2    -0.0930      0.035     -2.638      0.008      -0.162      -0.024
# LOGSIZE_t-1               0.7431      0.034     21.767      0.000       0.676       0.810
# LEVERAGE                 -0.1762      0.198     -0.891      0.373      -0.564       0.212
# INVEST_A                  7.8569      1.462      5.374      0.000       4.992      10.722
# LOGPPE_t-1               -0.4537      0.041    -11.065      0.000      -0.534      -0.373
# SALESGR                   0.9610      0.133      7.248      0.000       0.701       1.221
# ==============================================================================
# Omnibus:                    13540.523   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           123690.265
# Skew:                           0.546   Prob(JB):                         0.00
# Kurtosis:                       8.985   Cond. No.                         531.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
Y5 = reg_data2['RET_t+1']
X5 = reg_data2[['total_emission_scope2', 'LOGSIZE_t-1', 
                'LEVERAGE', 'INVEST_A', 'LOGPPE_t-1', 'SALESGR']]

############# year fixed effect ##############
year_dummies = pd.get_dummies(reg_data2['fyear'], prefix='year')
year_dummies = year_dummies.iloc[:, 1:]
year_dummies = year_dummies.astype(int)

############# month fixed effect ##############
month_dummies = pd.get_dummies(reg_data2['month'], prefix='month')
month_dummies = month_dummies.iloc[:, 1:]
month_dummies = month_dummies.astype(int)

X5 = pd.concat([X5, year_dummies], axis=1)
X5 = pd.concat([X5, month_dummies], axis=1)

X5 = sm.add_constant(X5)

model5 = sm.OLS(Y5, X5)

results5 = model5.fit()

print(results5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                RET_t+1   R-squared:                       0.042
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     133.7
# Date:                Mon, 24 Jun 2024   Prob (F-statistic):               0.00
# Time:                        01:39:16   Log-Likelihood:            -3.1198e+05
# No. Observations:               80201   AIC:                         6.240e+05
# Df Residuals:                   80174   BIC:                         6.243e+05
# Df Model:                          26
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -3.8275      0.678     -5.649      0.000      -5.155      -2.499
# total_emission_scope2    -0.0985      0.035     -2.804      0.005      -0.167      -0.030
# LOGSIZE_t-1               0.7365      0.034     21.719      0.000       0.670       0.803
# LEVERAGE                 -0.1535      0.194     -0.789      0.430      -0.535       0.228
# INVEST_A                  7.5026      1.449      5.176      0.000       4.662      10.344
# LOGPPE_t-1               -0.4550      0.041    -11.201      0.000      -0.535      -0.375
# SALESGR                   0.8557      0.133      6.435      0.000       0.595       1.116
# year_2012                 2.0226      0.666      3.035      0.002       0.716       3.329
# year_2013                 3.0400      0.629      4.831      0.000       1.807       4.273
# year_2014                 0.7058      0.617      1.145      0.252      -0.503       1.914
# year_2015                -0.1455      0.614     -0.237      0.813      -1.350       1.059
# year_2016                 1.1023      0.614      1.796      0.072      -0.100       2.305
# year_2017                 1.4668      0.603      2.431      0.015       0.284       2.649
# year_2018                 0.4145      0.603      0.687      0.492      -0.767       1.596
# year_2019                 1.0769      0.603      1.787      0.074      -0.105       2.258
# year_2020                 0.8018      0.605      1.326      0.185      -0.383       1.987
# month_2                   3.3399      0.204     16.378      0.000       2.940       3.740
# month_3                   1.4099      0.204      6.915      0.000       1.010       1.809
# month_4                  -3.6097      0.204    -17.713      0.000      -4.009      -3.210
# month_5                   4.1736      0.204     20.490      0.000       3.774       4.573
# month_6                   2.8935      0.203     14.221      0.000       2.495       3.292
# month_7                   2.6426      0.203     12.993      0.000       2.244       3.041
# month_8                   3.7824      0.203     18.604      0.000       3.384       4.181
# month_9                   1.0026      0.203      4.933      0.000       0.604       1.401
# month_10                  0.9375      0.203      4.616      0.000       0.539       1.336
# month_11                  0.0835      0.203      0.411      0.681      -0.315       0.482
# month_12                  3.8210      0.216     17.655      0.000       3.397       4.245
# ==============================================================================
# Omnibus:                    14668.247   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           123801.091
# Skew:                           0.644   Prob(JB):                         0.00
# Kurtosis:                       8.949   Cond. No.                         699.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
Y6 = reg_data2['RET_t+1']
X6 = reg_data2[['total_emission_scope2', 'LOGSIZE_t-1', 
                'LEVERAGE', 'INVEST_A', 'LOGPPE_t-1', 'SALESGR']]

############# year fixed effect ##############
year_dummies = pd.get_dummies(reg_data2['fyear'], prefix='year')
year_dummies = year_dummies.iloc[:, 1:]
year_dummies = year_dummies.astype(int)

############# month fixed effect ##############
month_dummies = pd.get_dummies(reg_data2['month'], prefix='month')
month_dummies = month_dummies.iloc[:, 1:]
month_dummies = month_dummies.astype(int)

############# industry fixed effect ##############
industry_dummies = pd.get_dummies(reg_data2['GICS_level_1'], prefix='industry')
industry_dummies = industry_dummies.iloc[:, 1:]
industry_dummies = industry_dummies.astype(int)

X6 = pd.concat([X6, year_dummies], axis=1)
X6 = pd.concat([X6, month_dummies], axis=1)
X6 = pd.concat([X6, industry_dummies], axis=1)

X6 = sm.add_constant(X6)

model6 = sm.OLS(Y6, X6)

results6 = model6.fit()

print(results6.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                RET_t+1   R-squared:                       0.043
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     99.25
# Date:                Mon, 24 Jun 2024   Prob (F-statistic):               0.00
# Time:                        02:34:42   Log-Likelihood:            -3.1194e+05
# No. Observations:               80201   AIC:                         6.239e+05
# Df Residuals:                   80164   BIC:                         6.243e+05
# Df Model:                          36
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              -4.0352      0.710     -5.680      0.000      -5.428      -2.643
# total_emission_scope2              -0.1138      0.041     -2.797      0.005      -0.194      -0.034
# LOGSIZE_t-1                         0.7716      0.037     20.791      0.000       0.699       0.844
# LEVERAGE                           -0.1703      0.195     -0.874      0.382      -0.552       0.211
# INVEST_A                            7.7242      1.529      5.051      0.000       4.727      10.722
# LOGPPE_t-1                         -0.4695      0.045    -10.509      0.000      -0.557      -0.382
# SALESGR                             0.8102      0.133      6.075      0.000       0.549       1.072
# year_2012                           2.0492      0.667      3.074      0.002       0.743       3.356
# year_2013                           3.0588      0.629      4.860      0.000       1.825       4.293
# year_2014                           0.7130      0.617      1.156      0.248      -0.496       1.922
# year_2015                          -0.1249      0.615     -0.203      0.839      -1.330       1.080
# year_2016                           1.1159      0.614      1.818      0.069      -0.087       2.319
# year_2017                           1.4604      0.604      2.420      0.016       0.277       2.643
# year_2018                           0.4178      0.603      0.693      0.489      -0.764       1.600
# year_2019                           1.0812      0.603      1.793      0.073      -0.101       2.263
# year_2020                           0.7950      0.605      1.314      0.189      -0.391       1.981
# month_2                             3.3402      0.204     16.387      0.000       2.941       3.740
# month_3                             1.4097      0.204      6.918      0.000       1.010       1.809
# month_4                            -3.6092      0.204    -17.720      0.000      -4.008      -3.210
# month_5                             4.1743      0.204     20.505      0.000       3.775       4.573
# month_6                             2.8944      0.203     14.233      0.000       2.496       3.293
# month_7                             2.6434      0.203     13.004      0.000       2.245       3.042
# month_8                             3.7834      0.203     18.619      0.000       3.385       4.182
# month_9                             1.0033      0.203      4.939      0.000       0.605       1.401
# month_10                            0.9382      0.203      4.621      0.000       0.540       1.336
# month_11                            0.0837      0.203      0.412      0.680      -0.314       0.482
# month_12                            3.8197      0.216     17.657      0.000       3.396       4.244
# industry_Consumer Discretionary     0.3624      0.237      1.531      0.126      -0.102       0.826
# industry_Consumer Staple           -0.1380      0.277     -0.499      0.618      -0.680       0.404
# industry_Energy                    -0.7592      0.295     -2.570      0.010      -1.338      -0.180
# industry_Financial                 -0.4501      0.248     -1.818      0.069      -0.935       0.035
# industry_Health Care                0.2032      0.236      0.861      0.389      -0.259       0.666
# industry_Industrial                 0.3264      0.225      1.448      0.148      -0.115       0.768
# industry_Information Technology     0.5497      0.231      2.375      0.018       0.096       1.003
# industry_Material                   0.5727      0.266      2.151      0.031       0.051       1.095
# industry_Real Estate               -0.9984      0.342     -2.922      0.003      -1.668      -0.329
# industry_Utilities                  0.4729      0.330      1.434      0.152      -0.174       1.119
# ==============================================================================
# Omnibus:                    14684.032   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           124016.728
# Skew:                           0.645   Prob(JB):                         0.00
# Kurtosis:                       8.954   Cond. No.                         700.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Regression on Emission Growth Scope1

# %%
shifted_columns1 = ['RET_t+1', 'RET1_t+1', 'emission_growth_scope1', 'LOGSIZE_t-1', 
                'LEVERAGE', 'INVEST_A', 'LOGPPE_t-1', 'SALESGR']
reg_data1 = regression_data_shifted.dropna(subset=shifted_columns1)

Y1 = reg_data1['RET_t+1']
X1 = reg_data1[['emission_growth_scope1', 'LOGSIZE_t-1', 
                'LEVERAGE', 'INVEST_A', 'LOGPPE_t-1', 'SALESGR']]

X1 = sm.add_constant(X1)

model1 = sm.OLS(Y1, X1)

results1 = model1.fit()

print(results1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               RET1_t+1   R-squared:                       0.069
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     987.0
# Date:                Mon, 24 Jun 2024   Prob (F-statistic):               0.00
# Time:                        02:51:41   Log-Likelihood:            -4.2904e+05
# No. Observations:               80201   AIC:                         8.581e+05
# Df Residuals:                   80194   BIC:                         8.582e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                    -12.3824      0.915    -13.529      0.000     -14.176     -10.588
# emission_growth_scope1     1.9240      0.606      3.173      0.002       0.735       3.113
# LOGSIZE_t-1                9.8435      0.144     68.490      0.000       9.562      10.125
# LEVERAGE                  -3.1229      0.837     -3.732      0.000      -4.763      -1.483
# INVEST_A                  59.3457      6.158      9.638      0.000      47.276      71.415
# LOGPPE_t-1                -7.7258      0.130    -59.225      0.000      -7.981      -7.470
# SALESGR                    6.7237      0.561     11.993      0.000       5.625       7.822
# ==============================================================================
# Omnibus:                    84223.139   Durbin-Watson:                   0.196
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         11785831.059
# Skew:                           5.038   Prob(JB):                         0.00
# Kurtosis:                      61.527   Cond. No.                         378.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
############# year fixed effect ##############
year_dummies = pd.get_dummies(reg_data1['fyear'], prefix='year')
year_dummies = year_dummies.iloc[:, 1:]
year_dummies = year_dummies.astype(int)

############# month fixed effect ##############
month_dummies = pd.get_dummies(reg_data1['month'], prefix='month')
month_dummies = month_dummies.iloc[:, 1:]
month_dummies = month_dummies.astype(int)

############# industry fixed effect ##############
industry_dummies = pd.get_dummies(reg_data1['GICS_level_1'], prefix='industry')
industry_dummies = industry_dummies.iloc[:, 1:]
industry_dummies = industry_dummies.astype(int)

# %%
Y2 = reg_data1['RET_t+1']
X2 = reg_data1[['emission_growth_scope1', 'LOGSIZE_t-1', 
                'LEVERAGE', 'INVEST_A', 'LOGPPE_t-1', 'SALESGR']]


X2 = pd.concat([X2, year_dummies], axis=1)
X2 = pd.concat([X2, month_dummies], axis=1)

X2 = sm.add_constant(X2)

model2 = sm.OLS(Y2, X2)

results2 = model2.fit()

print(results2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               RET1_t+1   R-squared:                       0.133
# Model:                            OLS   Adj. R-squared:                  0.132
# Method:                 Least Squares   F-statistic:                     471.5
# Date:                Mon, 24 Jun 2024   Prob (F-statistic):               0.00
# Time:                        01:47:48   Log-Likelihood:            -4.2619e+05
# No. Observations:               80201   AIC:                         8.524e+05
# Df Residuals:                   80174   BIC:                         8.527e+05
# Df Model:                          26
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                    -27.3593      2.702    -10.124      0.000     -32.656     -22.062
# emission_growth_scope1     1.1090      0.586      1.893      0.058      -0.039       2.257
# LOGSIZE_t-1                9.7804      0.140     69.706      0.000       9.505      10.055
# LEVERAGE                  -2.9102      0.808     -3.603      0.000      -4.494      -1.327
# INVEST_A                  88.5608      5.986     14.795      0.000      76.829     100.293
# LOGPPE_t-1                -7.7521      0.127    -61.151      0.000      -8.001      -7.504
# SALESGR                   10.1837      0.552     18.436      0.000       9.101      11.266
# year_2012                 18.2424      2.768      6.590      0.000      12.816      23.668
# year_2013                 36.2520      2.613     13.871      0.000      31.130      41.374
# year_2014                  7.6659      2.561      2.994      0.003       2.647      12.685
# year_2015                 -4.7617      2.552     -1.866      0.062      -9.763       0.240
# year_2016                 15.1731      2.548      5.954      0.000      10.178      20.168
# year_2017                 19.2701      2.505      7.691      0.000      14.359      24.181
# year_2018                 -7.4484      2.504     -2.975      0.003     -12.356      -2.541
# year_2019                 23.2104      2.502      9.277      0.000      18.307      28.114
# year_2020                 26.2519      2.509     10.465      0.000      21.335      31.169
# month_2                    0.4799      0.847      0.567      0.571      -1.180       2.140
# month_3                    0.5269      0.847      0.622      0.534      -1.133       2.187
# month_4                    0.4305      0.846      0.509      0.611      -1.229       2.090
# month_5                   -0.0514      0.846     -0.061      0.952      -1.710       1.607
# month_6                    0.3652      0.845      0.432      0.666      -1.291       2.022
# month_7                    0.4202      0.845      0.497      0.619      -1.236       2.076
# month_8                    0.6199      0.845      0.734      0.463      -1.035       2.275
# month_9                    0.6688      0.844      0.792      0.428      -0.986       2.323
# month_10                   0.6401      0.844      0.759      0.448      -1.014       2.294
# month_11                   0.2319      0.844      0.275      0.783      -1.422       1.886
# month_12                   1.2949      0.899      1.441      0.150      -0.467       3.057
# ==============================================================================
# Omnibus:                    87247.313   Durbin-Watson:                   0.221
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         14103057.180
# Skew:                           5.314   Prob(JB):                         0.00
# Kurtosis:                      67.089   Cond. No.                         499.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
Y3 = reg_data1['RET_t+1']
X3 = reg_data1[['emission_growth_scope1', 'LOGSIZE_t-1', 
                'LEVERAGE', 'INVEST_A', 'LOGPPE_t-1', 'SALESGR']]

X3 = pd.concat([X3, year_dummies], axis=1)
X3 = pd.concat([X3, month_dummies], axis=1)
X3 = pd.concat([X3, industry_dummies], axis=1)

X3 = sm.add_constant(X3)

model3 = sm.OLS(Y3, X3)

results3 = model3.fit()

print(results3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               RET1_t+1   R-squared:                       0.143
# Model:                            OLS   Adj. R-squared:                  0.142
# Method:                 Least Squares   F-statistic:                     370.1
# Date:                Mon, 24 Jun 2024   Prob (F-statistic):               0.00
# Time:                        01:47:55   Log-Likelihood:            -4.2573e+05
# No. Observations:               80201   AIC:                         8.515e+05
# Df Residuals:                   80164   BIC:                         8.519e+05
# Df Model:                          36
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                             -25.9268      2.828     -9.167      0.000     -31.470     -20.383
# emission_growth_scope1              1.4046      0.583      2.411      0.016       0.263       2.547
# LOGSIZE_t-1                        10.4007      0.151     68.931      0.000      10.105      10.696
# LEVERAGE                           -3.1154      0.805     -3.872      0.000      -4.693      -1.538
# INVEST_A                           84.1667      6.226     13.519      0.000      71.964      96.369
# LOGPPE_t-1                         -8.4344      0.143    -58.786      0.000      -8.716      -8.153
# SALESGR                             9.6885      0.551     17.580      0.000       8.608      10.769
# year_2012                          18.1855      2.755      6.601      0.000      12.786      23.585
# year_2013                          36.2482      2.601     13.938      0.000      31.151      41.345
# year_2014                           7.5956      2.548      2.980      0.003       2.601      12.591
# year_2015                          -4.6759      2.540     -1.841      0.066      -9.654       0.302
# year_2016                          15.1026      2.536      5.954      0.000      10.131      20.074
# year_2017                          18.8806      2.493      7.572      0.000      13.994      23.768
# year_2018                          -7.6755      2.492     -3.080      0.002     -12.559      -2.792
# year_2019                          23.0317      2.490      9.250      0.000      18.152      27.912
# year_2020                          25.9185      2.497     10.381      0.000      21.025      30.812
# month_2                             0.4825      0.842      0.573      0.567      -1.168       2.134
# month_3                             0.5245      0.842      0.623      0.533      -1.126       2.175
# month_4                             0.4347      0.842      0.516      0.606      -1.215       2.084
# month_5                            -0.0436      0.841     -0.052      0.959      -1.693       1.605
# month_6                             0.3716      0.840      0.442      0.658      -1.276       2.019
# month_7                             0.4267      0.840      0.508      0.612      -1.220       2.073
# month_8                             0.6282      0.840      0.748      0.454      -1.018       2.274
# month_9                             0.6736      0.839      0.802      0.422      -0.972       2.319
# month_10                            0.6413      0.839      0.764      0.445      -1.003       2.286
# month_11                            0.2285      0.839      0.272      0.785      -1.416       1.873
# month_12                            1.3114      0.894      1.467      0.142      -0.441       3.063
# industry_Consumer Discretionary     0.1791      0.959      0.187      0.852      -1.701       2.059
# industry_Consumer Staple           -4.7073      1.123     -4.193      0.000      -6.908      -2.507
# industry_Energy                    -8.9181      1.212     -7.357      0.000     -11.294      -6.542
# industry_Financial                -10.7076      1.023    -10.468      0.000     -12.712      -8.703
# industry_Health Care               -1.8376      0.975     -1.884      0.060      -3.749       0.074
# industry_Industrial                -0.4925      0.925     -0.532      0.595      -2.306       1.321
# industry_Information Technology     3.3845      0.955      3.545      0.000       1.513       5.256
# industry_Material                   3.8989      1.059      3.681      0.000       1.823       5.975
# industry_Real Estate              -19.1628      1.395    -13.738      0.000     -21.897     -16.429
# industry_Utilities                  8.5754      1.350      6.350      0.000       5.928      11.222
# ==============================================================================
# Omnibus:                    87498.684   Durbin-Watson:                   0.223
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         14350753.916
# Skew:                           5.336   Prob(JB):                         0.00
# Kurtosis:                      67.657   Cond. No.                         500.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Regression on Emission Growth Scope2

# %%
shifted_columns2 = ['RET_t+1', 'RET1_t+1', 'emission_growth_scope2', 'LOGSIZE_t-1', 
                'LEVERAGE', 'INVEST_A', 'LOGPPE_t-1', 'SALESGR']
reg_data2 = regression_data_shifted.dropna(subset=shifted_columns2)

Y4 = reg_data2['RET_t+1']
X4 = reg_data2[['emission_growth_scope2', 'LOGSIZE_t-1', 
                'LEVERAGE', 'INVEST_A', 'LOGPPE_t-1', 'SALESGR']]

X4 = sm.add_constant(X4)

model4 = sm.OLS(Y4, X4)

results4 = model4.fit()

print(results4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               RET1_t+1   R-squared:                       0.069
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     985.5
# Date:                Mon, 24 Jun 2024   Prob (F-statistic):               0.00
# Time:                        02:55:15   Log-Likelihood:            -4.2905e+05
# No. Observations:               80201   AIC:                         8.581e+05
# Df Residuals:                   80194   BIC:                         8.582e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                    -12.3208      0.917    -13.442      0.000     -14.117     -10.524
# emission_growth_scope2     0.7421      0.617      1.202      0.229      -0.468       1.952
# LOGSIZE_t-1                9.8410      0.144     68.453      0.000       9.559      10.123
# LEVERAGE                  -3.1084      0.837     -3.715      0.000      -4.748      -1.468
# INVEST_A                  59.4508      6.158      9.654      0.000      47.381      71.521
# LOGPPE_t-1                -7.7251      0.130    -59.217      0.000      -7.981      -7.469
# SALESGR                    6.7296      0.561     12.002      0.000       5.631       7.829
# ==============================================================================
# Omnibus:                    84203.239   Durbin-Watson:                   0.196
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         11767194.370
# Skew:                           5.037   Prob(JB):                         0.00
# Kurtosis:                      61.479   Cond. No.                         378.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
############# year fixed effect ##############
year_dummies = pd.get_dummies(reg_data2['fyear'], prefix='year')
year_dummies = year_dummies.iloc[:, 1:]
year_dummies = year_dummies.astype(int)

############# month fixed effect ##############
month_dummies = pd.get_dummies(reg_data2['month'], prefix='month')
month_dummies = month_dummies.iloc[:, 1:]
month_dummies = month_dummies.astype(int)

############# industry fixed effect ##############
industry_dummies = pd.get_dummies(reg_data2['GICS_level_1'], prefix='industry')
industry_dummies = industry_dummies.iloc[:, 1:]
industry_dummies = industry_dummies.astype(int)

# %%
Y5 = reg_data2['RET_t+1']
X5 = reg_data2[['emission_growth_scope2', 'LOGSIZE_t-1', 
                'LEVERAGE', 'INVEST_A', 'LOGPPE_t-1', 'SALESGR']]

X5 = pd.concat([X5, year_dummies], axis=1)
X5 = pd.concat([X5, month_dummies], axis=1)

X5 = sm.add_constant(X5)

model5 = sm.OLS(Y5, X5)

results5 = model5.fit()

print(results5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               RET1_t+1   R-squared:                       0.133
# Model:                            OLS   Adj. R-squared:                  0.132
# Method:                 Least Squares   F-statistic:                     471.4
# Date:                Mon, 24 Jun 2024   Prob (F-statistic):               0.00
# Time:                        06:35:47   Log-Likelihood:            -4.2619e+05
# No. Observations:               80201   AIC:                         8.524e+05
# Df Residuals:                   80174   BIC:                         8.527e+05
# Df Model:                          26
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                    -27.2982      2.702    -10.101      0.000     -32.595     -22.001
# emission_growth_scope2     0.3914      0.596      0.657      0.512      -0.777       1.560
# LOGSIZE_t-1                9.7786      0.140     69.675      0.000       9.503      10.054
# LEVERAGE                  -2.9013      0.808     -3.592      0.000      -4.485      -1.318
# INVEST_A                  88.6548      5.986     14.811      0.000      76.923     100.387
# LOGPPE_t-1                -7.7518      0.127    -61.147      0.000      -8.000      -7.503
# SALESGR                   10.1928      0.552     18.451      0.000       9.110      11.276
# year_2012                 18.1951      2.769      6.571      0.000      12.768      23.622
# year_2013                 36.2365      2.614     13.864      0.000      31.113      41.359
# year_2014                  7.6417      2.561      2.984      0.003       2.622      12.661
# year_2015                 -4.7784      2.552     -1.872      0.061      -9.781       0.224
# year_2016                 15.1457      2.549      5.943      0.000      10.150      20.141
# year_2017                 19.2437      2.506      7.680      0.000      14.333      24.155
# year_2018                 -7.4804      2.504     -2.987      0.003     -12.389      -2.572
# year_2019                 23.1897      2.502      9.268      0.000      18.285      28.094
# year_2020                 26.2483      2.509     10.462      0.000      21.331      31.166
# month_2                    0.4799      0.847      0.566      0.571      -1.181       2.140
# month_3                    0.5270      0.847      0.622      0.534      -1.133       2.187
# month_4                    0.4305      0.847      0.509      0.611      -1.229       2.090
# month_5                   -0.0508      0.846     -0.060      0.952      -1.709       1.608
# month_6                    0.3656      0.845      0.433      0.665      -1.291       2.022
# month_7                    0.4205      0.845      0.498      0.619      -1.235       2.076
# month_8                    0.6202      0.845      0.734      0.463      -1.035       2.275
# month_9                    0.6691      0.844      0.793      0.428      -0.986       2.324
# month_10                   0.6404      0.844      0.759      0.448      -1.013       2.294
# month_11                   0.2319      0.844      0.275      0.783      -1.422       1.886
# month_12                   1.2963      0.899      1.442      0.149      -0.466       3.058
# ==============================================================================
# Omnibus:                    87234.179   Durbin-Watson:                   0.221
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         14088989.363
# Skew:                           5.313   Prob(JB):                         0.00
# Kurtosis:                      67.056   Cond. No.                         499.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
Y6 = reg_data2['RET_t+1']
X6 = reg_data2[['emission_growth_scope2', 'LOGSIZE_t-1', 
                'LEVERAGE', 'INVEST_A', 'LOGPPE_t-1', 'SALESGR']]

X6 = pd.concat([X6, year_dummies], axis=1)
X6 = pd.concat([X6, month_dummies], axis=1)
X6 = pd.concat([X6, industry_dummies], axis=1)

X6 = sm.add_constant(X6)

model6 = sm.OLS(Y6, X6)

results6 = model6.fit()

print(results6.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               RET1_t+1   R-squared:                       0.142
# Model:                            OLS   Adj. R-squared:                  0.142
# Method:                 Least Squares   F-statistic:                     369.9
# Date:                Mon, 24 Jun 2024   Prob (F-statistic):               0.00
# Time:                        06:35:26   Log-Likelihood:            -4.2574e+05
# No. Observations:               80201   AIC:                         8.515e+05
# Df Residuals:                   80164   BIC:                         8.519e+05
# Df Model:                          36
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                             -25.8642      2.828     -9.145      0.000     -31.408     -20.321
# emission_growth_scope2              0.4808      0.593      0.810      0.418      -0.682       1.644
# LOGSIZE_t-1                        10.3976      0.151     68.894      0.000      10.102      10.693
# LEVERAGE                           -3.1038      0.805     -3.857      0.000      -4.681      -1.527
# INVEST_A                           84.3061      6.226     13.541      0.000      72.103      96.509
# LOGPPE_t-1                         -8.4335      0.143    -58.778      0.000      -8.715      -8.152
# SALESGR                             9.7009      0.551     17.601      0.000       8.621      10.781
# year_2012                          18.1283      2.755      6.579      0.000      12.728      23.529
# year_2013                          36.2313      2.601     13.930      0.000      31.133      41.329
# year_2014                           7.5669      2.549      2.969      0.003       2.572      12.562
# year_2015                          -4.6948      2.540     -1.848      0.065      -9.673       0.284
# year_2016                          15.0704      2.537      5.941      0.000      10.098      20.042
# year_2017                          18.8498      2.494      7.559      0.000      13.962      23.737
# year_2018                          -7.7139      2.492     -3.095      0.002     -12.598      -2.830
# year_2019                          23.0075      2.490      9.240      0.000      18.127      27.888
# year_2020                          25.9166      2.497     10.379      0.000      21.023      30.811
# month_2                             0.4825      0.842      0.573      0.567      -1.169       2.134
# month_3                             0.5246      0.842      0.623      0.533      -1.126       2.175
# month_4                             0.4348      0.842      0.517      0.605      -1.215       2.085
# month_5                            -0.0428      0.841     -0.051      0.959      -1.692       1.606
# month_6                             0.3721      0.840      0.443      0.658      -1.275       2.019
# month_7                             0.4271      0.840      0.508      0.611      -1.219       2.074
# month_8                             0.6285      0.840      0.748      0.454      -1.017       2.274
# month_9                             0.6741      0.839      0.803      0.422      -0.971       2.319
# month_10                            0.6418      0.839      0.765      0.444      -1.003       2.286
# month_11                            0.2285      0.839      0.272      0.785      -1.416       1.873
# month_12                            1.3132      0.894      1.469      0.142      -0.439       3.065
# industry_Consumer Discretionary     0.1855      0.959      0.193      0.847      -1.695       2.066
# industry_Consumer Staple           -4.6783      1.123     -4.167      0.000      -6.879      -2.478
# industry_Energy                    -8.8840      1.212     -7.329      0.000     -11.260      -6.508
# industry_Financial                -10.6733      1.023    -10.435      0.000     -12.678      -8.669
# industry_Health Care               -1.8152      0.975     -1.861      0.063      -3.727       0.097
# industry_Industrial                -0.4757      0.925     -0.514      0.607      -2.289       1.338
# industry_Information Technology     3.3922      0.955      3.552      0.000       1.521       5.264
# industry_Material                   3.9071      1.059      3.689      0.000       1.831       5.983
# industry_Real Estate              -19.1561      1.395    -13.732      0.000     -21.890     -16.422
# industry_Utilities                  8.5904      1.350      6.361      0.000       5.943      11.237
# ==============================================================================
# Omnibus:                    87480.630   Durbin-Watson:                   0.223
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         14331631.482
# Skew:                           5.335   Prob(JB):                         0.00
# Kurtosis:                      67.613   Cond. No.                         500.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
